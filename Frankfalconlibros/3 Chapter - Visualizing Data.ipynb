# %%
####### Chapter 3. Visualizing Data #######

# %%
import matplotlib.pyplot as plt

# %%
from collections import Counter

# %%
####def make_chart_simple_line_chart():####

# %%
    years = [1950, 1960, 1970, 1980, 1990, 2000, 2010]

# %%
    gdp = [300.2, 543.3, 1075.9, 2862.5, 5979.6, 10289.7, 14958.3]

# %%
    # create a line chart, years on x-axis, gdp on y-axis

# %%
    plt.plot(years, gdp, color='green', marker='o', linestyle='solid'); plt.title("Nominal GDP")
# Out:
# Text(0.5, 1.0, 'Nominal GDP')

# %%
    # add a title

# %%
    plt.title("Nominal GDP")
# Out:
# Text(0.5, 1.0, 'Nominal GDP')

# %%
    # add a label to the y-axis

# %%
    plt.ylabel("Billions of $")
# Out:
# Text(0, 0.5, 'Billions of $')

# %%
    plt.plot(years, gdp, color='green', marker='o', linestyle='solid'); plt.title("Nominal GDP");    plt.title("Nominal GDP");    plt.ylabel("Billions of $");    plt.show()

# %%
####def make_chart_simple_bar_chart():####

# %%
    movies = ["Annie Hall", "Ben-Hur", "Casablanca", "Gandhi", "West Side Story"]

# %%
    num_oscars = [5, 11, 3, 8, 10]

# %%
    # bars are by default width 0.8, so we'll add 0.1 to the left coordinates

# %%
    # so that each bar is centered

# %%
    xs = [i + 0.1 for i, _ in enumerate(movies)]

# %%
    # plot bars with left x-coordinates [xs], heights [num_oscars]

# %%
    plt.bar(xs, num_oscars)
# Out:
# <BarContainer object of 5 artists>

# %%
    plt.ylabel("# of Academy Awards")
# Out:
# Text(0, 0.5, '# of Academy Awards')

# %%
    plt.title("My Favorite Movies")
# Out:
# Text(0.5, 1.0, 'My Favorite Movies')

# %%
    # label x-axis with movie names at bar centers

# %%
    plt.xticks([i + 0.5 for i, _ in enumerate(movies)], movies)
# Out:
# ([<matplotlib.axis.XTick at 0x2006b139f60>,
# ...
#  <a list of 5 Text xticklabel objects>)

# %%
    plt.show()

# %%
    plt.bar(xs, num_oscars);    plt.ylabel("# of Academy Awards");    plt.title("My Favorite Movies");    plt.xticks([i + 0.5 for i, _ in enumerate(movies)], movies);    plt.show()

# %%
####def make_chart_histogram():####

# %%
    grades = [83,95,91,87,70,0,85,82,100,67,73,77,0]

# %%
    decile = lambda grade: grade // 10 * 10

# %%
    histogram = Counter(decile(grade) for grade in grades)

# %%
    plt.bar([x - 4 for x in histogram.keys()], # shift each bar to the left by 4
# Out:
#   File "<ipython-input-65-0807acff0348>", line 1
#     plt.bar([x - 4 for x in histogram.keys()], # shift each bar to the left by 4
#                                                                                 ^
# SyntaxError: unexpected EOF while parsing

# %%
           histogram.values(),                # give each bar its correct height
# Out:
# (dict_values([4, 2, 3, 2, 1, 1]),)

# %%
            8)                                 # give each bar a width of 8
# Out:
#   File "<ipython-input-67-a49777a0e5ab>", line 1
#     8)                                 # give each bar a width of 8
#      ^
# SyntaxError: invalid syntax

# %%
    plt.axis([-5, 105, 0, 5])                  # x-axis from -5 to 105,
# Out:
# [-5, 105, 0, 5]

# %%
                                               # y-axis from 0 to 5

# %%
    plt.xticks([10 * i for i in range(11)])    # x-axis labels at 0, 10, ..., 100
# Out:
# ([<matplotlib.axis.XTick at 0x2006b1b5ba8>,
# ...
#  <a list of 11 Text xticklabel objects>)

# %%
    plt.xlabel("Decile")
# Out:
# Text(0.5, 0, 'Decile')

# %%
    plt.ylabel("# of Students")
# Out:
# Text(0, 0.5, '# of Students')

# %%
    plt.title("Distribution of Exam 1 Grades")
# Out:
# Text(0.5, 1.0, 'Distribution of Exam 1 Grades')

# %%
    plt.show()

# %%
    plt.bar([x - 4 for x in histogram.keys()],histogram.values(),8)
# Out:
# <BarContainer object of 6 artists>

# %%
 plt.bar([x - 4 for x in histogram.keys()],histogram.values(),8);    plt.xticks([10 * i for i in range(11)]);    plt.xlabel("Decile");    plt.ylabel("# of Students");    plt.title("Distribution of Exam 1 Grades");    plt.show()

# %%
####def make_chart_misleading_y_axis(mislead=True):####

# %%
    mentions = [500, 505]

# %%
    years = [2013, 2014]

# %%
    plt.bar([2012.6, 2013.6], mentions, 0.8)
# Out:
# <BarContainer object of 2 artists>

# %%
    plt.xticks(years)
# Out:
# ([<matplotlib.axis.XTick at 0x2006c448828>,
# ...
#  <a list of 2 Text xticklabel objects>)

# %%
    plt.ylabel("# of times I heard someone say 'data science'")
# Out:
# Text(0, 0.5, "# of times I heard someone say 'data science'")

# %%
    # if you don't do this, matplotlib will label the x-axis 0, 1

# %%
    # and then add a +2.013e3 off in the corner (bad matplotlib!)

# %%
    plt.ticklabel_format(useOffset=False)

# %%
    if mislead:
# Out:
#   File "<ipython-input-87-a7720b8309a4>", line 1
#     if mislead:
#                ^
# SyntaxError: unexpected EOF while parsing

# %%
        # misleading y-axis only shows the part above 500

# %%
        plt.axis([2012.5,2014.5,499,506])
# Out:
# [2012.5, 2014.5, 499, 506]

# %%
        plt.title("Look at the 'Huge' Increase!")
# Out:
# Text(0.5, 1.0, "Look at the 'Huge' Increase!")

# %%
    else:
# Out:
#   File "<ipython-input-91-64c43b55f0b0>", line 1
#     else:
#        ^
# SyntaxError: invalid syntax

# %%
        plt.axis([2012.5,2014.5,0,550])
# Out:
# [2012.5, 2014.5, 0, 550]

# %%
        plt.title("Not So Huge Anymore.")
# Out:
# Text(0.5, 1.0, 'Not So Huge Anymore.')

# %%
    plt.show()

# %%
    plt.bar([2012.6, 2013.6], mentions, 0.8);    plt.xticks(years);    plt.ylabel("# of times I heard someone say 'data science'");    plt.axis([2012.5,2014.5,499,506]);        plt.title("Look at the 'Huge' Increase!");    plt.axis([2012.5,2014.5,0,550]);        plt.title("Not So Huge Anymore.");    plt.show()

# %%
####def make_chart_several_line_charts():####

# %%
    variance     = [1,2,4,8,16,32,64,128,256]

# %%
    bias_squared = [256,128,64,32,16,8,4,2,1]

# %%
    total_error  = [x + y for x, y in zip(variance, bias_squared)]

# %%
    xs = range(len(variance))

# %%
    # we can make multiple calls to plt.plot

# %%
    # to show multiple series on the same chart

# %%
    plt.plot(xs, variance,     'g-',  label='variance')    # green solid line

# %%
    plt.plot(xs, bias_squared, 'r-.', label='bias^2')      # red dot-dashed line

# %%
    plt.plot(xs, total_error,  'b:',  label='total error') # blue dotted line

# %%
    # because we've assigned labels to each series

# %%
    # we can get a legend for free

# %%
    # loc=9 means "top center"

# %%
    plt.legend(loc=9)
# Out:
# No handles with labels found to put in legend.

# %%
    plt.xlabel("model complexity")
# Out:
# Text(0.5, 0, 'model complexity')

# %%
    plt.title("The Bias-Variance Tradeoff")
# Out:
# Text(0.5, 1.0, 'The Bias-Variance Tradeoff')

# %%
    plt.show()

# %%
    plt.plot(xs, variance,     'g-',  label='variance');    plt.plot(xs, bias_squared, 'r-.', label='bias^2');    plt.plot(xs, total_error,  'b:',  label='total error');    plt.legend(loc=9);    plt.xlabel("model complexity");    plt.title("The Bias-Variance Tradeoff");    plt.show()

# %%
####def make_chart_scatter_plot():####

# %%
    friends = [ 70, 65, 72, 63, 71, 64, 60, 64, 67]

# %%
    minutes = [175, 170, 205, 120, 220, 130, 105, 145, 190]

# %%
    labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i']

# %%
    plt.scatter(friends, minutes)

# %%
    # label each point

# %%
    for label, friend_count, minute_count in zip(labels, friends, minutes):        plt.annotate(label,                     xy=(friend_count, minute_count),                     xytext=(5, -5),                     textcoords='offset points')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-326bfc39c26d> in <module>
# ----> 1 for label, friend_count, minute_count in zip(labels, friends, minutes):        plt.annotate(label,                     xy=(friend_count, minute_count),                     xytext=(5, -5),                     textcoords='offset points')
#
# NameError: name 'labels' is not defined

# %%
        plt.annotate(label,
# Out:
#   File "<ipython-input-120-ab759a9d1f49>", line 1
#     plt.annotate(label,
#                        ^
# SyntaxError: unexpected EOF while parsing

# %%
                     xy=(friend_count, minute_count), # put the label with its point
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-121-ee7e655acce0> in <module>
# ----> 1 xy=(friend_count, minute_count), # put the label with its point
#
# NameError: name 'friend_count' is not defined

# %%
                     xytext=(5, -5), # but slightly offset

# %%
                     textcoords='offset points')
# Out:
#   File "<ipython-input-123-ff983208ad4c>", line 1
#     textcoords='offset points')
#                               ^
# SyntaxError: invalid syntax

# %%
    plt.title("Daily Minutes vs. Number of Friends")
# Out:
# Text(0.5, 1.0, 'Daily Minutes vs. Number of Friends')

# %%
    plt.xlabel("# of friends")
# Out:
# Text(0.5, 0, '# of friends')

# %%
    plt.ylabel("daily minutes spent on the site")
# Out:
# Text(0, 0.5, 'daily minutes spent on the site')

# %%
    plt.show()

# %%
for label, friend_count, minute_count in zip(labels, friends, minutes):        plt.annotate(label,                     xy=(friend_count, minute_count),                     xytext=(5, -5),                     textcoords='offset points')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-326bfc39c26d> in <module>
# ----> 1 for label, friend_count, minute_count in zip(labels, friends, minutes):        plt.annotate(label,                     xy=(friend_count, minute_count),                     xytext=(5, -5),                     textcoords='offset points')
#
# NameError: name 'labels' is not defined

# %%
    for label, friend_count, minute_count in zip(labels, friends, minutes): plt.annotate(label,xy=(friend_count, minute_count),xytext=(5, -5),textcoords='offset points');    plt.title("Daily Minutes vs. Number of Friends");    plt.xlabel("# of friends");    plt.ylabel("daily minutes spent on the site");    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-5def871dc466> in <module>
# ----> 1 for label, friend_count, minute_count in zip(labels, friends, minutes): plt.annotate(label,xy=(friend_count, minute_count),xytext=(5, -5),textcoords='offset points');    plt.title("Daily Minutes vs. Number of Friends");    plt.xlabel("# of friends");    plt.ylabel("daily minutes spent on the site");    plt.show()
#
# NameError: name 'labels' is not defined

# %%
###Al parecer no esta definida las etiquetas, creo ques un definición como en el anterior ejercicio###

# %%
####def make_chart_scatterplot_axes(equal_axes=False):####

# %%
def make_chart_scatterplot_axes(equal_axes=False):
# Out:
#   File "<ipython-input-25-35a37d16a29d>", line 1
#     def make_chart_scatterplot_axes(equal_axes=False):
#                                                       ^
# SyntaxError: unexpected EOF while parsing

# %%
import matplotlib.pyplot as plt

# %%
    test_1_grades = [ 99, 90, 85, 97, 80]

# %%
    test_2_grades = [100, 85, 60, 90, 70]

# %%
    plt.scatter(test_1_grades, test_2_grades)

# %%
    plt.xlabel("test 1 grade")
# Out:
# Text(0.5, 0, 'test 1 grade')

# %%
    plt.ylabel("test 2 grade")
# Out:
# Text(0, 0.5, 'test 2 grade')

# %%
    if equal_axes:
# Out:
#   File "<ipython-input-45-9f02c4986065>", line 1
#     if equal_axes:
#                   ^
# SyntaxError: unexpected EOF while parsing

# %%
        plt.title("Axes Are Comparable")
# Out:
# Text(0.5, 1.0, 'Axes Are Comparable')

# %%
        plt.axis("equal")
# Out:
# (-0.05500000000000001,
#  0.05500000000000001,
#  -0.05500000000000001,
#  0.05500000000000001)

# %%
    else:
# Out:
#   File "<ipython-input-48-64c43b55f0b0>", line 1
#     else:
#        ^
# SyntaxError: invalid syntax

# %%
        plt.title("Axes Aren't Comparable")
# Out:
# Text(0.5, 1.0, "Axes Aren't Comparable")

# %%
    plt.show()

# %%
    plt.scatter(test_1_grades, test_2_grades);    plt.xlabel("test 1 grade");    plt.ylabel("test 2 grade");        plt.title("Axes Are Comparable");        plt.axis("equal");        plt.title("Axes Aren't Comparable");    plt.show()

# %%
def make_chart_pie_chart():
# Out:
#   File "<ipython-input-52-b64a5b79d102>", line 1
#     def make_chart_pie_chart():
#                                ^
# SyntaxError: unexpected EOF while parsing

# %%
    plt.pie([0.95, 0.05], labels=["Uses pie charts", "Knows better"])
# Out:
# ([<matplotlib.patches.Wedge at 0x221bd2aba90>,
# ...
#  [Text(-1.086457168210212, 0.17207795223283895, 'Uses pie charts'),
#   Text(1.0864571621685486, -0.17207799037838706, 'Knows better')])

# %%
    # make sure pie is a circle and not an oval

# %%
    plt.axis("equal")
# Out:
# (-0.05500000000000001,
#  0.05500000000000001,
#  -0.05500000000000001,
#  0.05500000000000001)

# %%
    plt.show()

# %%
    plt.pie([0.95, 0.05], labels=["Uses pie charts", "Knows better"]);    plt.axis("equal");    plt.show()
